# %%
Testdata : https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data

# %%
- Find out the average of M = malignant and  B = benign 
- How much area is impacted area_mean
- Area impacted for diagnosis
- count of M and B
- what is the max area size of benign which becomes M(find the threshold area size and diameter)
-- find out the threshold for all of the columns for B
-- mean, mode,median for Malignant only 
-- How many sizeof(avg perimeter for Malignant)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("breastCancer.csv")
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df.diagnosis.unique()
# conclusion: i have M,B as an unique diagnosis
# Out:
# array(['M', 'B'], dtype=object)

# %%
df.isnull().sum()
# here i conclude that there are no nan present in my dataset
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# Find out the average of M = malignant and  B = benign

# %%
df.diagnosis.duplicated().sum()
# Out:
# 567

# %%
df.count()
# Out:
# id                         569
# diagnosis                  569
# radius_mean                569
# texture_mean               569
# perimeter_mean             569
# area_mean                  569
# smoothness_mean            569
# compactness_mean           569
# concavity_mean             569
# concave points_mean        569
# symmetry_mean              569
# fractal_dimension_mean     569
# radius_se                  569
# texture_se                 569
# perimeter_se               569
# area_se                    569
# smoothness_se              569
# compactness_se             569
# concavity_se               569
# concave points_se          569
# symmetry_se                569
# fractal_dimension_se       569
# radius_worst               569
# texture_worst              569
# perimeter_worst            569
# area_worst                 569
# smoothness_worst           569
# compactness_worst          569
# concavity_worst            569
# concave points_worst       569
# ...

# %% [markdown]
# conclusion : Found the mean of diagnosis where M and B has area mean , i also found the max of B and M. I founf the threshold of B and M

# %%
# as_index=False allow you to check the condition on a common column and not on an index
df_by_diagnosis_areamean=df.groupby("diagnosis", as_index=False).area_mean
df_by_diagnosis_areamean
df_by_diagnosis_areamean.max()
# Out:
#   diagnosis  area_mean
# 0         B      992.1
# 1         M     2501.0

# %% [markdown]
# - what is the max area size of benign which becomes M(find the threshold area size and diameter)

# %%
df_ben=df[df.area_mean>992.1]
df_ben
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38           122.8     1001.0
# 1      842517         M        20.57         17.77           132.9     1326.0
# 2    84300903         M        19.69         21.25           130.0     1203.0
# 4    84358402         M        20.29         14.34           135.1     1297.0
# 6      844359         M        18.25         19.98           119.6     1040.0
# ..        ...       ...          ...           ...             ...        ...
# 535    919555         M        20.55         20.86           137.8     1308.0
# 563    926125         M        20.92         25.09           143.0     1347.0
# 564    926424         M        21.56         22.39           142.0     1479.0
# 565    926682         M        20.13         28.25           131.2     1261.0
# 567    927241         M        20.60         29.33           140.1     1265.0
#
# ...

# %%
df_ben.diagnosis.unique()
# Out:
# array(['M'], dtype=object)

# %%
df_ben.diagnosis.count()
# Out:
# 94

# %%
# This is tell you the numbers of M which is not needed as per the above case
# df_malig=df[df.area_mean<=2501.0]
# df_malig
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 461  911296202         M        27.42         26.27           186.9
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 461     2501.0           0.1084            0.1988          0.3635
#
#      concave points_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 461               0.1689  ...          31.37            251.2      4254.0
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 461            0.1357             0.4256           0.6833
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst  \
# 461                0.2625          0.2641                  0.07427
#
#      Unnamed: 32
# 461          NaN
#
# [1 rows x 33 columns]

# %% [markdown]
# mean, mode,median for Malignant only

# %% [markdown]
# Conclusion: We have used only the values which are B and found the mean

# %%
df_ben.area_mean.mean()
# Out:
# 1301.3393617021277

# %%
df_ben.area_mean.mode()
# Out:
# 0    1075.0
# 1    1076.0
# 2    1138.0
# 3    1214.0
# 4    1264.0
# dtype: float64

# %%
df_ben.area_mean.median()
# Out:
# 1226.5

# %% [markdown]
# How many avg perimeter for Malignant

# %%
avg_perimeter_mal=df_ben.perimeter_mean.mean()
# Out:
# 134.97127659574463

# %% [markdown]
# Find out the avg M and avg ben

# %%
df_by_avg=df_by_diagnosis_areamean.count()
# Out:
# diagnosis      B
# area_mean    357
# Name: 0, dtype: object

# %%
type(df_by_avg)
# Out:
# pandas.core.frame.DataFrame

# %%
df_by_avg[df_by_avg.diagnosis=='B']
# Out:
#   diagnosis  area_mean
# 0         B        357

# %%
df_by_avg[df_by_avg.diagnosis=='M']
# Out:
#   diagnosis  area_mean
# 1         M        212

# %%
df_by_count=df_by_avg[df_by_avg.diagnosis=='B'].area_mean[0]
df_by_count
# Out:
# 357

# %%
df_by_average_b=df_by_count/len(df)
df_by_average_b
# Out:
# 0.6274165202108963

# %%
df_by_count_M=df_by_avg[df_by_avg.diagnosis=='M'].area_mean[1]
df_by_count_M
df_by_average_M=df_by_count_M/len(df)
df_by_average_M
# Out:
# 0.37258347978910367
