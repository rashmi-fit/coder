# %% [markdown]
# As a part of this i will learn read csv, analyse data ,i will try to find out the unique columns and perform some operations on it. And i will also do a basic plot using matplot lib

# %% [markdown]
# Used this dataset from Kaggle https://www.kaggle.com/datasets/mysarahmadbhat/lung-cancer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("survey lung cancer.csv")
df
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
df.head()

# %%
df.tail()

# %%
df.columns

# %%
df.shape

# %%
df.info()

# %%
df.dtypes

# %%
df.LUNG_CANCER.unique()

# %%
df.AGE.unique()

# %%
df.SMOKING.unique()

# %%
df.GENDER.unique()

# %%
df.isnull().sum()

# %%
df.SMOKING.isnull().sum()

# %%
df.AGE.isnull().sum()

# %%
df.LUNG_CANCER.isnull().sum()

# %% [markdown]
# <b>Conslusion:<b> i didnt find any of the field with null value

# %%
df=df.dropna()
df.count()

# %%
df.AGE.dropna()
df.AGE.count()

# %%
df.SMOKING.dropna()
df.SMOKING.count()

# %%
df.GENDER.dropna()
df.GENDER.count()

# %%
df.LUNG_CANCER.dropna()
df.LUNG_CANCER.count()

# %% [markdown]
# Duplicated records if any

# %%
df.duplicated().sum()

# %%
df.AGE.duplicated().sum()

# %%
df.GENDER.duplicated().sum()

# %%
df.SMOKING.duplicated().sum()

# %%
df.LUNG_CANCER.duplicated().sum()

# %% [markdown]
# This will remove if the column has duplicates

# %%
df.drop_duplicates(subset="AGE",keep="first",inplace=True)
df.count()

# %%
df.drop_duplicates(subset="GENDER",keep="first",inplace=True)
df.count()

# %%
df.drop_duplicates(subset="SMOKING",keep="first",inplace=True)
df.count()

# %%
df.drop_duplicates(subset="LUNG_CANCER",keep="first",inplace=True)
df.count()

# %% [markdown]
# Now i am doing filtering on M/F

# %%
df[df.GENDER == 'M']

# %%
df[df.GENDER == 'F']

# %%
df

# %% [markdown]
# my problem statement : i wanted to see how many F /M involved in smoking, lungs cancer and within which age

# %%
df=pd.read_csv("survey lung cancer.csv")
df
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
df.tail()
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 304         2                    2                      2           1
# ...

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
df.GENDER.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df.AGE.unique()
# Out:
# array([69, 74, 59, 63, 75, 52, 51, 68, 53, 61, 72, 60, 58, 48, 57, 44, 64,
#        21, 65, 55, 62, 56, 67, 77, 70, 54, 49, 73, 47, 71, 66, 76, 78, 81,
#        79, 38, 39, 87, 46])

# %%
df.LUNG_CANCER.unique()
# Out:
# array(['YES', 'NO'], dtype=object)

# %%
df.SMOKING.unique()

# Smoking: YES=2 , NO=1
# Out:
# array([1, 2])

# %% [markdown]
# In 1st two filters, thinking to keep only smoking & lung cancer rows

# %%
df_new = df[(df.SMOKING == 2) & (df.LUNG_CANCER == 'YES')]
df_new.head(2)
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 1      M   74        2               1        1              1
# 6      M   52        2               1        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 1                2         2         2         1                  1         1
# 6                1         2         1         2                  2         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 1                    2                      2           2         YES
# 6                    2                      1           2         YES

# %% [markdown]
# remaining rows, I can groupby (gender, age) and get the count

# %%
df_by_gender_age = df.groupby(["GENDER","AGE"]).count()

# %%
df_by_gender_age
# Out:
#             SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  \
# GENDER AGE
# F      21         1               1        1              1                1
#        38         1               1        1              1                1
#        44         1               1        1              1                1
#        47         2               2        2              2                2
#        48         1               1        1              1                1
# ...             ...             ...      ...            ...              ...
# M      75         2               2        2              2                2
#        76         2               2        2              2                2
#        77         4               4        4              4                4
#        78         1               1        1              1                1
#        79         1               1        1              1                1
#
# ...

# %% [markdown]
# u should use df_new in groupby

# %%
df_by_gender_age = df_new.groupby(["GENDER","AGE"]).count()

# %%
df_by_gender_age
# Out:
#             SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  \
# GENDER AGE
# F      44         1               1        1              1                1
#        47         2               2        2              2                2
#        51         5               5        5              5                5
#        53         1               1        1              1                1
#        54         6               6        6              6                6
#        55         4               4        4              4                4
#        56         3               3        3              3                3
#        58         2               2        2              2                2
#        59         2               2        2              2                2
#        60         3               3        3              3                3
#        61         8               8        8              8                8
# ...

# %% [markdown]
# now draw some plot

# %%
plt.plot(df_by_gender_age)
plt.title("LUNG_CANCER Analysis")
plt.xlabel("LUNG_CANCER")
plt.ylabel("AGE")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3j/j_x0d91n629d7vft3083cdxm0000gq/T/ipykernel_6863/1691396652.py in <module>
# ----> 1 plt.plot(df_by_gender_age)
#       2 plt.title("LUNG_CANCER Analysis")
#       3 plt.xlabel("LUNG_CANCER")
#       4 plt.ylabel("AGE")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
# ...
